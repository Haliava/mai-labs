# %%
from PIL import Image


def uint32_le_hex(value):
  return value.to_bytes(4, 'little').hex()


def convert_img_to_data(in_filename, out_filename):
  in_image = Image.open(in_filename)
  in_pixels = list(in_image.getdata())
  [img_w, img_h] = in_image.size
  img_data = [[0] * img_w for _ in range(img_h)]
  for i in range(img_w):
    for j in range(img_h):
      r, g, b = in_pixels[i * img_w + j]
      img_data[i][j] = f'{r:02x}{g:02x}{b:02x}00'.upper()
  
  with open(out_filename, 'w+') as output:
    output.write(f'{uint32_le_hex(img_w)} {uint32_le_hex(img_h)}\n')
    print(img_w, img_h)
    for i in range(img_h):
      output.write(' '.join(img_data[i]) + '\n')
    print(' '.join(img_data[0]))

convert_img_to_data('../out/minecraft-block.jpg', '../out/minecraft-block.data')
# Out:
# 360 360
# C8BD8F00 C8BD8F00 C8BD8F00 C8BD8F00 C8BD8F00 C8BD8F00 C8BD8F00 C8BD8F00 C9BE9000 C6BB8D00 CABF9100 C6BB8D00 C9BE9000 C9BE9000 C5BA8C00 D9CF9E00 E4DAA700 E3D9A400 E2D8A300 E3D9A400 E4DAA500 E4DAA500 E3D9A400 E2D8A300 E3D9A400 E3D9A400 E3D9A400 E3D9A400 E3D9A400 E3D9A400 E3D9A400 E3D9A400 E3D9A800 E3D9A800 E3D9A800 E3D9A800 E3D9A800 E3D9A800 E3D9A800 E3D9A800 E3D9A800 E3D9A800 E3D9A600 E3D9A600 E3D9A600 E3D9A600 E3D9A600 E3D9A600 E3D8AA00 E3D8AA00 E3D8AA00 E3D8AA00 E3D8AA00 E3D8AA00 E3D8AA00 E3D8AA00 E2D7A900 E4D9AB00 E4D9AB00 E2D7A900 E3D8AA00 E5DAAC00 E2D7A900 DED4A300 DBD49E00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DED59E00 DDD49D00 DDD39E00 DED49F00 DDD39E00 DCD29D00 E1D7A600 E7DDAC00 E7DCAE00 E7DCAE00 E7DCAF00 E7DCAF00 E7DBB100 E7DBB100 E7DBB100 E7DCAF00 E7DDAC00 E7DDAA00 E7DDAA00 E7DDAA00 E7DDAA00 E7DDAA00 E7DDAA00 E7DDAA00 E6DCA900 E8DEAB00 E8DEAB00 E7DDAA00 E8DEAB00 E8DEAB00 E3D9A600 DCD29D00 DBD49E00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DCD59E00 DAD39C00 DAD39C00 DBD49D00 DCD59E00 DAD39C00 D5CE9700 D1CA9300 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D2CB9400 D5CE9700 D9D29B00 DCD59E00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD49D00 DBD59B00 DAD59B00 DAD69900 D9D49A00 D9D49A00 DBD49E00 DED7A100 E5DBAA00 E9DFAE00 E7DCAE00 E7DCAE00 E8DBAE00 E8DBAE00 E9DBAE00 E9DBAE00 E9DBAC00 E8DCAC00 E5DEAA00 E4DEAA00 E4DEAC00 E4DEAC00 E4DEAE00 E4DEAE00 E4DEAE00 E4DEAE00 E5DFAF00 E3DDAB00 E3DDAB00 E5DFAB00 E4DFA800 DFDAA300 DBD69E00 DAD59D00 DBD49E00 DBD49E00 DBD49E00 DBD49E00 DBD49E00 DBD49E00 DBD49E00 DBD49E00 DBD49E00 DBD49E00 DBD49E00 DBD49E00 DBD49E00 DBD49E00 DBD49E00 DBD49E00 DCD59E00 DAD39C00 DBD49D00 DDD69F00 DBD49D00 D5CE9700 D2CB9500 D2CB9500 D2CB9500 D2CB9500 D4CA9700 D4CA9700 D4CA9700 D4CA9700 D4CA9900 D2CA9900 D2CA9B00 D1CB9900 D1CB9900 D1CC9500 D1CC9500 D1CC9400 D2CC9200 D2CC9200 D1CB9100 D2CC9200 D1CA9300 D0C99200 D6CC9900 DDD3A000 E0D6A500 DFD5A200 E0D6A300 E0D6A100 E0D6A100 E0D6A100 E0D6A100 E0D6A100 E0D6A100 E0D6A100 E0D6A100 E0D6A100 E0D6A100 E0D6A100 E0D6A100 E0D6A100 E0D6A100 E0D6A100 DFD5A400 DFD5A400 DFD5A400 DFD5A400 DED4A300 DDD3A200 DDD3A200 DCD2A100 DCD2A100 DCD2A100 DCD2A100 DCD2A100 DCD2A100 DCD2A100 DCD2A100 DAD2A300 DAD1A800 D9D2A800 DAD1A800 DAD2A400 DCD1A300 DCD29F00 DDD19F00 DDD19D00 DDD3A000 DAD09F00 DBD3A400 D6CFA300 E5DDB600 FDF7D300 FBF7D400 F8F4D100 F8F5D200 F8F6D000 F8F6D000 F8F6D000 F8F6D000 F8F6D000 F8F6D000 F8F6D000 F8F6D000 F8F6D000 F8F6D000 F8F6D000 F8F6D000 F8F6D000 F8F6D000 F8F6D000 F8F5D200 F9F7D100 F9F5CF00 FAF7CC00 E1DAAC00 C5BF8D00 CBC49000 CBC48E00 CDC38E00 CDC38E00 CBC49000 CBC39200 CAC49400 CAC39500 C8C39900 C8C49500 CBC49000 CBC48D00 CBC48D00 CBC48D00 CBC48D00 CBC48D00 CBC48D00 CBC48D00 CAC38C00 CCC58E00 C8C18A00 CBC48D00 D7D09900 DAD39C00 D7D09900 DAD39C00 D9D29B00 D9D29B00 D9D29B00 D9D29B00 D9D29B00 D9D29B00 D9D29B00 D9D29B00

# %%
from PIL import Image
import os


def uint32_le_hex(value):
  return value.to_bytes(4, 'little').hex()


def convert_img_to_data(in_filename, out_filename):
  in_image = Image.open(in_filename)
  in_pixels = list(in_image.getdata())
  [img_w, img_h] = in_image.size
  img_data = [[0] * img_w for _ in range(img_h)]
  for i in range(img_h):
    for j in range(img_w):
      r, g, b = in_pixels[i * img_w + j]
      img_data[i][j] = f'{r:02x}{g:02x}{b:02x}00'
  
  with open(out_filename, 'wb') as output:
    output.write(img_w.to_bytes(4, 'little'))
    output.write(img_h.to_bytes(4, 'little'))
    output.write(in_image.convert('RGBA').tobytes())


def convert_data_to_img(in_data_filename, out_image_filename):
  with open(in_data_filename, 'rb') as input_file:
    img_w = int.from_bytes(input_file.read(4), 'little')
    img_h = int.from_bytes(input_file.read(4), 'little')
    raw_pixel_data = input_file.read()

  rgb_data = bytearray()
  for i in range(0, len(raw_pixel_data), 4):
    rgb_data.extend(raw_pixel_data[i: i + 3])

  restored_image = Image.frombytes(
    mode='RGB',
    size=(img_w, img_h),
    data=bytes(rgb_data)
  )

  restored_image.save(out_image_filename)


def convert_folder_to_data(folder_path, out_folder_path):
  for filename in os.listdir(folder_path):
    convert_img_to_data(os.path.join(folder_path, filename), os.path.join(out_folder_path, filename.split('.')[0] + '.data'))



def convert_folder_to_img(folder_path, out_folder_path):
  for filename in os.listdir(folder_path):
    convert_data_to_img(os.path.join(folder_path, filename), os.path.join(out_folder_path, filename.split('.')[0] + '.jpg'))

# convert_folder_to_data('../in', '../out')
convert_folder_to_img('../processed', '../result')
# convert_data_to_img('./mash2.data', './res-mash2.jpg')
# convert_img_to_data('../out/mash2.jpg', '../out/mash2.data')

# %%
(123).to_bytes(4, 'little').hex()
# Out:
# '7b000000'
